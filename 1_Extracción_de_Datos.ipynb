# %% [markdown]
# <a href="https://colab.research.google.com/github/YaellOrtega/ctividad-1-Extracci-n-de-Datos-/blob/main/1_Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
# Convertir en dataframe
df=pd.read_csv("CountryTable.csv")
# df

# %% [markdown]
# **FILTROS BASICOS ARA VARIABLES CUALITATIVAS**

# %%
# El filtro 1 "filtro por objeto" se aplico en la columna "continent" para obtener los registros que solo contengan la categoria "Africa"
filtro1=df[df["continent"]=="Africa"]
filtro1
# Out:
#     code                                   name continent           region  \
# 2    AGO                                 Angola    Africa   Central Africa
# 17   BDI                                Burundi    Africa   Eastern Africa
# 19   BEN                                  Benin    Africa   Western Africa
# 20   BFA                           Burkina Faso    Africa   Western Africa
# 35   BWA                               Botswana    Africa  Southern Africa
# 36   CAF               Central African Republic    Africa   Central Africa
# 42   CIV                           Cote dIvoire    Africa   Western Africa
# 43   CMR                               Cameroon    Africa   Central Africa
# 44   COD  Congo, The Democratic Republic of the    Africa   Central Africa
# 45   COG                                  Congo    Africa   Central Africa
# 48   COM                                Comoros    Africa   Eastern Africa
# ...

# %%
# El filtro 2 "filtro por filas" se aplico en las filas 5 a 23 no consecutivamente
# filtro2=df.iloc[300:302,:]
filtro2=df.iloc[ 5:23 , : ] #filas no consecutivas
filtro2
# Out:
#    code                         name      continent  \
# 5   AND                      Andorra         Europe
# 6   ANT         Netherlands Antilles  North America
# 7   ARE         united Arab Emirates           Asia
# 8   ARG                    Argentina  South America
# 9   ARM                      Armenia           Asia
# 10  ASM               American Samoa        Oceania
# 11  ATA                   Antarctica     Antarctica
# 12  ATF  French Southern territories     Antarctica
# 13  ATG          Antigua and Barbuda  North America
# 14  AuS                    Australia        Oceania
# 15  AuT                      Austria         Europe
# 16  AZE                   Azerbaijan           Asia
# 17  BDI                      Burundi         Africa
# 18  BEL                      Belgium         Europe
# 19  BEN                        Benin         Africa
# 20  BFA                 Burkina Faso         Africa
# 21  BGD                   Bangladesh           Asia
# ...

# %%
# El filtro 3 "filtro por columnas" se aplico en las columnas 3, 6 y 9 no consecutivamente
# filtro3=df.iloc[:,4:7]
filtro3=df.iloc[:,[3,6,9]] #columnas no consecutivas
filtro3
# Out:
#                         region  population   gnp_old
# 0                    Caribbean      103000     793.0
# 1    Southern and Central Asia    22720000       NaN
# 2               Central Africa    12878000    7984.0
# 3                    Caribbean        8000       NaN
# 4              Southern Europe     3401200    2500.0
# ..                         ...         ...       ...
# 234                Middle East    18112000    5729.0
# 235            Southern Europe    10640000       NaN
# 236            Southern Africa    40377000  129092.0
# 237             Eastern Africa     9169000    3922.0
# 238             Eastern Africa    11669000    8670.0
#
# [239 rows x 3 columns]

# %%
df= pd.read_csv("CountryTable.csv", index_col=2)
df
# Out:
#               code          name                     region  surface_area  \
# continent
# North America  ABW         Aruba                  Caribbean         193.0
# Asia           AFG   Afghanistan  Southern and Central Asia      652090.0
# Africa         AGO        Angola             Central Africa     1246700.0
# North America  AIA      Anguilla                  Caribbean          96.0
# Europe         ALB       Albania            Southern Europe       28748.0
# ...            ...           ...                        ...           ...
# Asia           YEM         Yemen                Middle East      527968.0
# Europe         YuG    Yugoslavia            Southern Europe      102173.0
# Africa         ZAF  South Africa            Southern Africa     1221037.0
# Africa         ZMB        Zambia             Eastern Africa      752618.0
# Africa         ZWE      Zimbabwe             Eastern Africa      390757.0
#
# ...

# %%
# El filtro 4 "filtro de filas vs columnas" se aplico en la columna "gnp" para obtener los registros que solo contengan la categoria "Africa" o "Asia"

# Paso 2: Se aplico el filtro de filas vs columnas
filtro4=df.loc[["Africa","Asia"], ["gnp"]]
filtro4
# Out:
#                 gnp
# continent
# Africa       6648.0
# Africa        903.0
# Africa       2357.0
# Africa       2425.0
# Africa       4834.0
# ...             ...
# Asia       210721.0
# Asia       256254.0
# Asia        14194.0
# Asia        21929.0
# Asia         6041.0
#
# [109 rows x 1 columns]

# %%
# El filtro 5 "filtro por cabecera" se aplico en la cabecera
filtro5=df.head(10)
filtro5
# Out:
#               code                  name                     region  \
# continent
# North America  ABW                 Aruba                  Caribbean
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# North America  AIA              Anguilla                  Caribbean
# Europe         ALB               Albania            Southern Europe
# Europe         AND               Andorra            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
# South America  ARG             Argentina              South America
# Asia           ARM               Armenia                Middle East
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# North America         193.0                NaN      103000             78.4
# ...

# %% [markdown]
# **FILTROS BASICOS PARA VARIABLES CUANTITATIVAS**

# %%
# El filtro 6 "filtro por comparacion" se aplico en la columna "gnp" para obtener los registros que solo contengan datos menor a "2005"
filtro6=df[df["gnp"]<2005]
filtro6
# Out:
#               code                     name           region  surface_area  \
# continent
# North America  ABW                    Aruba        Caribbean         193.0
# North America  AIA                 Anguilla        Caribbean          96.0
# Europe         AND                  Andorra  Southern Europe         468.0
# North America  ANT     Netherlands Antilles        Caribbean         800.0
# Asia           ARM                  Armenia      Middle East       29800.0
# ...            ...                      ...              ...           ...
# North America  VGB  Virgin Islands, British        Caribbean         151.0
# North America  VIR     Virgin Islands, u.S.        Caribbean         347.0
# Oceania        VuT                  Vanuatu        Melanesia       12189.0
# Oceania        WLF        Wallis and Futuna        Polynesia         200.0
# Oceania        WSM                    Samoa        Polynesia        2831.0
#
# ...

# %%
# El filtro 7 "filtro Y" se aplico en la columna "gnp" para obtener los registros mayores a "200000" y "name" igual a "Belgium"
filtro7=df[(df["population"]>200000) & (df["name"]=="Belgium")]
filtro7
# Out:
#           code     name          region  surface_area  independence_year  \
# continent
# Europe     BEL  Belgium  Western Europe       30518.0             1830.0
#
#            population  life_expectancy       gnp   gnp_old       local_name  \
# continent
# Europe       10239000             77.8  249704.0  243948.0  Belgie/Belgique
#
#                                government_form head_of_state  capital code2
# continent
# Europe     Constitutional Monarchy, Federation     Albert II    179.0    BE

# %%
# El filtro 8 "filtro O" se aplico en la columna "gnp" para obtener los registros que solo contengan la categoria mayor a "200000" o "name" igual a "Belgium"
filtro8=df[(df["population"]>200000) | (df["name"]=="Belgium")]
filtro8
# Out:
#               code                  name                     region  \
# continent
# Asia           AFG           Afghanistan  Southern and Central Asia
# Africa         AGO                Angola             Central Africa
# Europe         ALB               Albania            Southern Europe
# North America  ANT  Netherlands Antilles                  Caribbean
# Asia           ARE  united Arab Emirates                Middle East
# ...            ...                   ...                        ...
# Asia           YEM                 Yemen                Middle East
# Europe         YuG            Yugoslavia            Southern Europe
# Africa         ZAF          South Africa            Southern Africa
# Africa         ZMB                Zambia             Eastern Africa
# Africa         ZWE              Zimbabwe             Eastern Africa
#
#                surface_area  independence_year  population  life_expectancy  \
# continent
# ...

# %%
# El filtro 9 "filtro NOT" se aplico en la columna "gnp" para no obtener los registros que contengan la categoria mayor o igual "200000" y tampoco "name" igual a "Belgium"
filtro9=df[~(df["population"]>=200000) & ~(df["name"]=="Belgium")]
filtro9
# Out:
#               code                                          name  \
# continent
# North America  ABW                                         Aruba
# North America  AIA                                      Anguilla
# Europe         AND                                       Andorra
# Oceania        ASM                                American Samoa
# Antarctica     ATA                                    Antarctica
# Antarctica     ATF                   French Southern territories
# North America  ATG                           Antigua and Barbuda
# North America  BMu                                       Bermuda
# Antarctica     BVT                                 Bouvet Island
# Oceania        CCK                       Cocos (Keeling) Islands
# Oceania        COK                                  Cook Islands
# Oceania        CXR                              Christmas Island
# North America  CYM                                Cayman Islands
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Entregable1.csv")

# %%
#descargar archivo filtrado en csv
from google.colab import files
files.download ("Entregable1.csv")
